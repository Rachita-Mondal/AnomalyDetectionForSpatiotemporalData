# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
LRSTSS = pd.read_csv("LRSTSS_varying_amp.csv")
LRSTS = pd.read_csv("LRSTS_varying_amp.csv")
HORPCA = pd.read_csv("HORPCA_varying_amp.csv")
LRSSS =  pd.read_csv("LRSSS_varying_amp.csv")

# %%
   
    fig = plt.figure(figsize=(12, 4))
    
    ax1 = plt.subplot(1, 2, 1) 
    sns.lineplot(data=LRSTSS[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc",marker = 'o', label='LRSTSS', errorbar= ('ci', 95))
    sns.lineplot(data=LRSTS[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc", marker='o', label = 'LRSTS', errorbar = ('ci', 95))
    sns.lineplot(data=LRSSS[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc",marker = 'o', label = 'LRSSS', errorbar = ('ci', 95))
    sns.lineplot(data=HORPCA[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc",marker = 'o', label = 'HORPCA', errorbar = ('ci', 95))
    ax1.set_xlabel("Radius", fontsize = 14)
    ax1.set_ylabel("AUC Score", fontsize = 14)
    ax1.grid(True)
    ax1.legend()
    handles, labels = ax1.get_legend_handles_labels() 
    ax1.legend().remove()

    plt.subplot(1, 2, 2) 

    
    sns.lineplot(data=LRSTSS[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score",marker = 'o',errorbar= ('ci', 95))
    sns.lineplot(data=LRSTS[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score", marker = 'o',errorbar= ('ci', 95))
    sns.lineplot(data=LRSSS[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score", marker = 'o',errorbar= ('ci', 95))
    sns.lineplot(data=HORPCA[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score", marker = 'o',errorbar= ('ci', 95))
    #plt.title("F1_score for varying duration with NoG = 450, r = 2, d = 10")
    plt.xlabel("Amplitude", fontsize = 14)
    plt.ylabel("F1 Score", fontsize = 14)
    #plt.tight_layout()
    plt.grid(True)
    #plt.legend(loc = 'best', bbox_to_anchor=(1, 1))
    
    
    # --- GLOBAL LEGEND ---
    fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4, bbox_to_anchor=(0.519, 1.02), fontsize = 14)
    
    # --- Final layout ---
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()
