# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "/Users/rachitamondal/Desktop/Anomaly_Detection/Results/Varying_Radius/"
LRSTSS_rad = pd.read_csv(file + "LRSTSS_varying_rad.csv")
LRSTS_rad = pd.read_csv(file + "LRSTS_varying_rad.csv")
HORPCA_rad = pd.read_csv(file + "HORPCA_varying_rad.csv")
LRSSS_rad =  pd.read_csv(file + "LRSSS_varying_rad.csv")

file = "/Users/rachitamondal/Desktop/Anomaly_Detection/Results/Varying_Duration/"
LRSTSS_dur = pd.read_csv(file + "LRSTSS_varying_dur.csv")
LRSTS_dur = pd.read_csv(file + "LRSTS_varying_dur.csv")
HORPCA_dur = pd.read_csv(file + "HORPCA_varying_dur.csv")
LRSSS_dur =  pd.read_csv(file + "LRSSS_varying_dur.csv")

file = "/Users/rachitamondal/Desktop/Anomaly_Detection/Results/Varying_Group/"
LRSTSS_noa = pd.read_csv(file + "LRSTSS_varying_noa.csv")
LRSTS_noa = pd.read_csv(file + "LRSTS_varying_noa.csv")
HORPCA_noa = pd.read_csv(file + "HORPCA_varying_noa.csv")
LRSSS_noa =  pd.read_csv(file + "LRSSS_varying_noa.csv")

# %%
LRSTSS_rad
# Out:
#      seed  radius  duration  noa  F1_score   roc_auc
# 0       1       1         4  100  0.461503  0.806336
# 1       2       1         4  100  0.432544  0.769475
# 2       3       1         4  100  0.419494  0.755668
# 3       4       1         4  100  0.521998  0.914158
# 4       5       1         4  100  0.454734  0.836427
# ..    ...     ...       ...  ...       ...       ...
# 245    46       5         4  100  0.772252  0.888590
# 246    47       5         4  100  0.773270  0.937441
# 247    48       5         4  100  0.720993  0.928012
# 248    49       5         4  100  0.810042  0.916438
# 249    50       5         4  100  0.808738  0.919212
#
# [250 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(16, 8))

# Labels for subplots
subplot_labels = ['(i)', '(ii)', '(iii)', '(iv)', '(v)', '(vi)']

# --- SUBPLOT 1 ---
ax1 = plt.subplot(2, 3, 1)
sns.lineplot(data=LRSTSS_rad, x="radius", y="roc_auc", marker='o', errorbar=('ci', 95), label="LR-STSS")
sns.lineplot(data=LRSTS_rad, x="radius", y="roc_auc", marker='o', errorbar=('ci', 95), label="LR-TS")
sns.lineplot(data=LRSSS_rad, x="radius", y="roc_auc", marker='o', errorbar=('ci', 95), label="LR-SS")
sns.lineplot(data=HORPCA_rad, x="radius", y="roc_auc", marker='o', errorbar=('ci', 95), label="HoRPCA")
ax1.set_ylim(0.7, 0.95)
ax1.set_xlabel("Radius", fontsize = 14)
ax1.set_ylabel("AUC-ROC Score", fontsize = 14)
ax1.grid(True)
ax1.set_title(subplot_labels[0], loc='center', fontsize=14)
ax1.legend_.remove()  # remove local legend
handles, labels = ax1.get_legend_handles_labels()  # Save correct handles

# --- SUBPLOT 2 ---
ax2 = plt.subplot(2, 3, 2)
sns.lineplot(data=LRSTSS_dur, x="duration", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_dur, x="duration", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_dur, x="duration", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_dur, x="duration", y="roc_auc", marker='o', errorbar=('ci', 95))
ax2.set_ylim(0.7, 0.95)
ax2.set_xlabel("Duration", fontsize = 14)
ax2.set_ylabel("AUC-ROC Score", fontsize = 14)
ax2.grid(True)
ax2.set_title(subplot_labels[1], loc='center', fontsize=14)

# --- SUBPLOT 3 ---
ax3 = plt.subplot(2, 3, 3)
sns.lineplot(data=LRSTSS_noa, x="noa", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_noa, x="noa", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_noa, x="noa", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_noa, x="noa", y="roc_auc", marker='o', errorbar=('ci', 95))
ax3.set_ylim(0.7, 0.95)
ax3.set_xlabel("Number of groups", fontsize = 14)
ax3.set_ylabel("AUC-ROC Score", fontsize = 14)
ax3.grid(True)
ax3.set_title(subplot_labels[2], loc='center', fontsize=14)

# --- SUBPLOT 4 ---
ax4 = plt.subplot(2, 3, 4)
sns.lineplot(data=LRSTSS_rad, x="radius", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_rad, x="radius", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_rad, x="radius", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_rad, x="radius", y="F1_score", marker='o', errorbar=('ci', 95))
ax4.set_ylim(0.2, 0.85)
ax4.set_xlabel("Radius", fontsize = 14)
ax4.set_ylabel("F1 Score",fontsize = 14)
ax4.grid(True)
ax4.set_title(subplot_labels[3], loc='center', fontsize=14)

# --- SUBPLOT 5 ---
ax5 = plt.subplot(2, 3, 5)
sns.lineplot(data=LRSTSS_dur, x="duration", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_dur, x="duration", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_dur, x="duration", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_dur, x="duration", y="F1_score", marker='o', errorbar=('ci', 95))
ax5.set_ylim(0.2, 0.85)
ax5.set_xlabel("Duration", fontsize = 14)
ax5.set_ylabel("F1 Score", fontsize = 14)
ax5.grid(True)
ax5.set_title(subplot_labels[4], loc='center', fontsize=14)

# --- SUBPLOT 6 ---
ax6 = plt.subplot(2, 3, 6)
sns.lineplot(data=LRSTSS_noa, x="noa", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_noa, x="noa", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_noa, x="noa", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_noa, x="noa", y="F1_score", marker='o', errorbar=('ci', 95))
ax6.set_ylim(0.2, 0.85)
ax6.set_xlabel("Number of groups", fontsize = 14)
ax6.set_ylabel("F1 Score", fontsize = 14)
ax6.grid(True)
ax6.set_title(subplot_labels[5], loc='center', fontsize=14)

# --- GLOBAL LEGEND ---
fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4, bbox_to_anchor=(0.519, 1.02), fontsize=14)

# --- Final layout ---
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
file = "/Users/rachitamondal/Desktop/Anomaly_Detection/Results/Varying_Amplitude/"
LRSTSS_amp = pd.read_csv(file+"LRSTSS_varying_amp.csv")
LRSTS_amp = pd.read_csv(file+"LRSTS_varying_amp.csv")
HORPCA_amp = pd.read_csv(file+"HORPCA_varying_amp.csv")
LRSSS_amp =  pd.read_csv(file+"LRSSS_varying_amp.csv")

file = "/Users/rachitamondal/Desktop/Anomaly_Detection/Results/Varying_SNR/"
LRSTSS_snr = pd.read_csv(file+"LRSTSS_varying_snr.csv")
LRSTS_snr = pd.read_csv(file+"LRSTS_varying_snr.csv")
HORPCA_snr = pd.read_csv(file+"HORPCA_varying_snr.csv")
LRSSS_snr =  pd.read_csv(file+"LRSSS_varying_snr.csv")

# %%
LRSTSS_snr
# Out:
#      seed  radius  duration  noa  snr  F1_score   roc_auc
# 0       1       2        10  450    5  0.661737  0.836590
# 1       2       2        10  450    5  0.689419  0.860402
# 2       3       2        10  450    5  0.694676  0.864399
# 3       4       2        10  450    5  0.692975  0.866386
# 4       5       2        10  450    5  0.679067  0.859522
# ..    ...     ...       ...  ...  ...       ...       ...
# 245    46       2        10  450   25  0.873009  0.950948
# 246    47       2        10  450   25  0.789357  0.913295
# 247    48       2        10  450   25  0.818726  0.919017
# 248    49       2        10  450   25  0.807260  0.911259
# 249    50       2        10  450   25  0.853716  0.939742
#
# [250 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec

# %%
fig = plt.figure(figsize=(10, 6))

# Labels for subplots
subplot_labels = ['(i)', '(iii)', '(ii)', '(iv)']

# --- SUBPLOT 1 ---
ax1 = plt.subplot(2, 2, 1)
sns.lineplot(data=LRSTSS_amp, x="amplitude", y="roc_auc", marker='o', errorbar=('ci', 95), label="LR-STSS")
sns.lineplot(data=LRSTS_amp, x="amplitude", y="roc_auc", marker='o', errorbar=('ci', 95), label="LR-TS")
sns.lineplot(data=LRSSS_amp, x="amplitude", y="roc_auc", marker='o', errorbar=('ci', 95), label="LR-SS")
sns.lineplot(data=HORPCA_amp, x="amplitude", y="roc_auc", marker='o', errorbar=('ci', 95), label="HoRPCA")
#ax1.set_ylim(0.7, 0.95)
ax1.set_xlabel("Amplitude")
ax1.set_ylabel("AUC-ROC Score")
ax1.grid(True)
ax1.set_title(subplot_labels[0], loc='center')
ax1.legend_.remove()  # remove local legend
handles, labels = ax1.get_legend_handles_labels()  # Save correct handles

# --- SUBPLOT 2 ---
ax2 = plt.subplot(2, 2, 2)
sns.lineplot(data=LRSTSS_snr, x="snr", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_snr, x="snr", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_snr, x="snr", y="roc_auc", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_snr, x="snr", y="roc_auc", marker='o', errorbar=('ci', 95))
#ax2.set_ylim(0.7, 0.95)
ax2.set_xlabel("SNR")
ax2.set_ylabel("AUC-ROC Score")
ax2.grid(True)
ax2.set_title(subplot_labels[1], loc='center')

# --- SUBPLOT 5 ---
ax3 = plt.subplot(2, 2, 3)
sns.lineplot(data=LRSTSS_amp, x="amplitude", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_amp, x="amplitude", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_amp, x="amplitude", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_amp, x="amplitude", y="F1_score", marker='o', errorbar=('ci', 95))
#ax5.set_ylim(0.2, 0.85)
ax3.set_xlabel("Amplitude")
ax3.set_ylabel("F1 Score")
ax3.grid(True)
ax3.set_title(subplot_labels[2], loc='center')
#ax5.set_title(subplot_labels[1], loc='center', fontsize=14)

# --- SUBPLOT 6 ---
ax4 = plt.subplot(2, 2, 4)
sns.lineplot(data=LRSTSS_snr, x="snr", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSTS_snr, x="snr", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=LRSSS_snr, x="snr", y="F1_score", marker='o', errorbar=('ci', 95))
sns.lineplot(data=HORPCA_snr, x="snr", y="F1_score", marker='o', errorbar=('ci', 95))
#ax6.set_ylim(0.2, 0.85)
ax4.set_xlabel("SNR")
ax4.set_ylabel("F1 Score")
ax4.grid(True)
ax4.set_title(subplot_labels[3], loc='center')
#ax6.set_title(subplot_labels[5], loc='center', fontsize=14)

# --- GLOBAL LEGEND ---
fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4, bbox_to_anchor=(0.519, 1.02))

# --- Final layout ---
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()
