# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
LRSTSS = pd.read_csv("LRSTSS_varying_amp.csv")
LRSTS = pd.read_csv("LRSTS_varying_amp.csv")
HORPCA = pd.read_csv("HORPCA_varying_amp.csv")
LRSSS =  pd.read_csv("LRSSS_varying_amp.csv")

# %%
   
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1) 
    sns.lineplot(data=LRSTSS[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc",marker = 'o',errorbar= ('ci', 95))
    sns.lineplot(data=LRSTS[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc", marker='o', errorbar = ('ci', 95))
    sns.lineplot(data=LRSSS[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc",marker = 'o',errorbar = ('ci', 95))
    sns.lineplot(data=HORPCA[["seed", "amplitude", "roc_auc"]], x="amplitude", y="roc_auc",marker = 'o',errorbar = ('ci', 95))
    
    plt.title("AUC for varying duration with NoG = 450, r = 2, d = 10")
    plt.xlabel("Amplitude")
    plt.ylabel("AUC")
    #plt.tight_layout()
    plt.grid(True)
   

    plt.subplot(1, 2, 2) 

    
    sns.lineplot(data=LRSTSS[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score", label='LRSTSS',marker = 'o',errorbar= ('ci', 95))
    sns.lineplot(data=LRSTS[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score", label='LRSTS',marker = 'o',errorbar= ('ci', 95))
    sns.lineplot(data=LRSSS[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score", label='LRSSS',marker = 'o',errorbar= ('ci', 95))
    sns.lineplot(data=HORPCA[["seed", "amplitude", "F1_score"]], x="amplitude", y="F1_score", label='HORPCA',marker = 'o',errorbar= ('ci', 95))
    plt.title("F1_score for varying duration with NoG = 450, r = 2, d = 10")
    plt.xlabel("Amplitude")
    plt.ylabel("F1_score")
    #plt.tight_layout()
    plt.grid(True)
    plt.legend(loc = 'best', bbox_to_anchor=(1, 1))
    
    
    
    
    plt.show()
