# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
LRSTSS = pd.read_csv("LRSTSS_varying_noa.csv")
LRSTS = pd.read_csv("LRSTS_varying_noa.csv")
HORPCA = pd.read_csv("HORPCA_varying_noa.csv")
LRSSS =  pd.read_csv("LRSSS_varying_noa.csv")

# %%
    
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1) 
    sns.lineplot(data=LRSTSS[["seed", "noa", "roc_auc"]], x="noa", y="roc_auc",errorbar= ('ci', 95))
    sns.lineplot(data=LRSTS[["seed", "noa", "roc_auc"]], x="noa", y="roc_auc",errorbar = ('ci', 95))
    sns.lineplot(data=LRSSS[["seed", "noa", "roc_auc"]], x="noa", y="roc_auc",errorbar = ('ci', 95))
    sns.lineplot(data=HORPCA[["seed", "noa", "roc_auc"]], x="noa", y="roc_auc",errorbar = ('ci', 95))
    plt.ylim(0.7,0.95 )
    plt.title("AUC for varying groups with r = 1, d = 1")
    plt.xlabel("Number of groups")
    plt.ylabel("AUC")
    #plt.tight_layout()
    plt.grid(True)
   

    plt.subplot(1, 2, 2) 

    
    sns.lineplot(data=LRSTSS[["seed", "noa", "F1_score"]], x="noa", y="F1_score", label='LRSTSS',errorbar= ('ci', 95))
    sns.lineplot(data=LRSTS[["seed", "noa", "F1_score"]], x="noa", y="F1_score", label='LRSTS',errorbar= ('ci', 95))
    sns.lineplot(data=LRSSS[["seed", "noa", "F1_score"]], x="noa", y="F1_score", label='LRSSS',errorbar= ('ci', 95))
    sns.lineplot(data=HORPCA[["seed", "noa", "F1_score"]], x="noa", y="F1_score", label='HORPCA',errorbar= ('ci', 95))
    plt.ylim(0.2,0.85 )
    plt.title("F1_score for varying groups with r = 1, d = 1")
    plt.xlabel("Number of groups")
    plt.ylabel("F1_score")
    #plt.tight_layout()
    plt.grid(True)
    plt.legend( bbox_to_anchor=(1, 1))
    
    
    
    
    plt.show()
